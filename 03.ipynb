# %%
class Parent:
    def __init__(self):
        pass

    def hello(self):
        print("ครับ")

# %%
class Child(Parent):
    def __init__(self):
        pass

    def hello(self):
        print("สวัสดีครับ")

# %%
Person = Child()
Person.hello()
# Out:
# สวัสดีครับ
