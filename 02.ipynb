# %%
from datetime import datetime

class DigitClock:
    def __init__(self):
        pass

    def showTime(self):
        now = datetime.now()
        current_time = now.strftime("%H:%M:%S")
        print("เวลาปัจจุบัน : {}".format(current_time))

# %%
from datetime import date

class Calendar:
    def __init__(self):
        pass

    def showDate(self):
        today = date.today()
        print("วันที่ปัจจุบัน : {}".format(today))

# %%
clock = DigitClock()
clock.showTime()
# Out:
# เวลาปัจจุบัน : 10:36:22
